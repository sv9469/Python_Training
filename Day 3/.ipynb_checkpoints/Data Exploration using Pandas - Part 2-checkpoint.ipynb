# %% [markdown]
# ## Data Exploration using Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv', sep = '|')

# %% [markdown]
# #### Adding, Subtracting, Concatenating columns

# %%
df['Age']+df['Fare']
# Out:
# 0       29.2500
# 1      109.2833
# 2       33.9250
# 3       88.1000
# 4       43.0500
# 5           NaN
# 6      105.8625
# 7       23.0750
# 8       38.1333
# 9       44.0708
# 10      20.7000
# 11      84.5500
# 12      28.0500
# 13      70.2750
# 14      21.8542
# 15      71.0000
# 16      31.1250
# 17          NaN
# 18      49.0000
# 19          NaN
# 20      61.0000
# 21      47.0000
# 22      23.0292
# 23      63.5000
# 24      29.0750
# 25      69.3875
# 26          NaN
# 27     282.0000
# 28          NaN
# 29          NaN
# 30      67.7208
# 31          NaN
# 32          NaN
# 33      76.5000
# 34     110.1708
# 35      94.0000
# 36          NaN
# 37      29.0500
# 38      36.0000
# 39      25.2417
# 40      49.4750
# 41      48.0000
# 42          NaN
# 43      44.5792
# 44      26.8792
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49      35.8000
# 50      46.6875
# 51      28.8000
# 52     125.7292
# 53      55.0000
# 54     126.9792
# 55          NaN
# 56      31.5000
# 57      35.7292
# 58      32.7500
# 59      57.9000
# 60      29.2292
# 61     118.0000
# 62     128.4750
# 63      31.9000
# 64          NaN
# 65          NaN
# 66      39.5000
# 67      27.1583
# 68      24.9250
# 69      34.6625
# 70      42.5000
# 71      62.9000
# 72      94.5000
# 73      40.4542
# 74      88.4958
# 75      32.6500
# 76          NaN
# 77          NaN
# 78      29.8300
# 79      42.4750
# 80      31.0000
# 81      38.5000
# 82          NaN
# 83      75.1000
# 84      27.5000
# 85      48.8500
# 86      50.3750
# 87          NaN
# 88     286.0000
# 89      32.0500
# 90      37.0500
# 91      27.8542
# 92     107.1750
# 93      46.5750
# 94      66.2500
# 95          NaN
# 96     105.6542
# 97      86.3583
# 98      57.0000
# 99      60.0000
# 100     35.8958
# 101         NaN
# 102     98.2875
# 103     41.6542
# 104     44.9250
# 105     35.8958
# 106     28.6500
# 107         NaN
# 108     45.8958
# 109         NaN
# 110     99.0000
# 111     28.9542
# 112     30.0500
# 113     29.8250
# 114     31.4583
# 115     28.9250
# 116     78.2500
# 117     50.0000
# 118    271.5208
# 119     33.2750
# 120     94.5000
# 121         NaN
# 122     62.5708
# 123     45.5000
# 124    131.2875
# 125     23.2417
# 126         NaN
# 127     31.1417
# 128         NaN
# 129     51.9750
# 130     40.8958
# 131     27.0500
# 132     61.5000
# 133     55.0000
# 134     38.0000
# 135     38.0458
# 136     45.2833
# 137     90.1000
# 138     25.2167
# 139    103.2000
# 140         NaN
# 141     29.7500
# 142     39.8500
# 143     25.7500
# 144     29.5000
# 145     55.7500
# 146     34.7958
# 147     43.3750
# 148     62.5000
# 149     55.0000
# 150     63.5250
# 151     88.6000
# 152     63.5500
# 153     55.0000
# 154         NaN
# 155    112.3792
# 156     23.7333
# 157     38.0500
# 158         NaN
# 159         NaN
# 160     60.1000
# 161     55.7500
# 162     33.7750
# 163     25.6625
# 164     40.6875
# 165     29.5250
# 166         NaN
# 167     72.9000
# 168         NaN
# 169     84.4958
# 170     94.5000
# 171     33.1250
# 172     12.1333
# 173     28.9250
# 174     86.6958
# 175     25.8542
# 176         NaN
# 177     78.7125
# 178     43.0000
# 179     36.0000
# 180         NaN
# 181         NaN
# 182     40.3875
# 183     40.0000
# 184     26.0250
# 185         NaN
# 186         NaN
# 187     71.5500
# 188     55.5000
# 189     43.8958
# 190     45.0000
# 191     32.0000
# 192     26.8542
# 193     29.0000
# 194     71.7208
# 195    204.5208
# 196         NaN
# 197     50.4042
# 198         NaN
# 199     37.0000
# 200     37.5000
# 201         NaN
# 202     40.4958
# 203     52.7250
# 204     26.0500
# 205     12.4625
# 206     47.8500
# 207     44.7875
# 208     23.7500
# 209     71.0000
# 210     31.0500
# 211     56.0000
# 212     29.2500
# 213     43.0000
# 214         NaN
# 215    144.2750
# 216     34.9250
# 217     69.0000
# 218    108.2917
# 219     40.5000
# 220     24.0500
# 221     40.0000
# 222     59.0500
# 223         NaN
# 224    128.0000
# 225     31.3500
# 226     29.5000
# 227     27.7500
# 228     31.0000
# 229         NaN
# 230    118.4750
# 231     36.7750
# 232     72.5000
# 233     36.3875
# 234     34.5000
# 235         NaN
# 236     70.0000
# 237     34.2500
# 238     29.5000
# 239     45.2750
# 240         NaN
# 241         NaN
# 242     39.5000
# 243     29.1250
# 244     37.2250
# 245    134.0000
# 246     32.7750
# 247     38.5000
# 248     89.5542
# 249     80.0000
# 250         NaN
# 251     39.4625
# 252     88.5500
# 253     46.1000
# 254     61.2125
# 255     44.2458
# 256         NaN
# 257    116.5000
# 258    547.3292
# 259     76.0000
# 260         NaN
# 261     34.3875
# 262    131.6500
# 263     40.0000
# 264         NaN
# 265     46.5000
# 266     55.6875
# 267     32.7750
# 268    211.4625
# 269    170.6333
# 270         NaN
# 271     25.0000
# 272     60.5000
# 273     66.7000
# 274         NaN
# 275    140.9583
# 276     52.7500
# 277         NaN
# 278     36.1250
# 279     55.2500
# 280     72.7500
# 281     35.8542
# 282     25.5000
# 283     27.0500
# 284         NaN
# 285     41.6625
# 286     39.5000
# 287     29.8958
# 288     55.0000
# 289     29.7500
# 290    104.8500
# 291    110.0792
# 292     48.8750
# 293     32.8500
# 294     31.8958
# 295         NaN
# 296     30.7292
# 297    153.5500
# 298         NaN
# 299    297.5208
# 300         NaN
# 301         NaN
# 302     19.0000
# 303         NaN
# 304         NaN
# 305    152.4700
# 306         NaN
# 307    125.9000
# 308     54.0000
# 309     86.9292
# 310    107.1583
# 311    280.3750
# 312     52.0000
# 313     35.8958
# 314     69.2500
# 315     33.8542
# 316     50.0000
# 317     68.0000
# 318    195.8667
# 319    174.5000
# 320     29.2500
# 321     34.8958
# 322     42.3500
# 323     51.0000
# 324         NaN
# 325    171.6333
# 326     67.2375
# 327     49.0000
# 328     51.5250
# 329     73.9792
# 330         NaN
# 331     74.0000
# 332    191.4625
# 333     34.0000
# 334         NaN
# 335         NaN
# 336     95.6000
# 337    175.5000
# 338     53.0500
# 339     80.5000
# 340     28.0000
# 341    287.0000
# 342     41.0000
# 343     38.0000
# 344     49.0000
# 345     37.0000
# 346     53.0000
# 347         NaN
# 348     18.9000
# 349     50.6625
# 350     32.2250
# 351         NaN
# 352     22.2292
# 353     42.8000
# 354         NaN
# 355     37.5000
# 356     77.0000
# 357     51.0000
# 358         NaN
# 359         NaN
# 360     67.9000
# 361     56.7208
# 362     59.4542
# 363     42.0500
# 364         NaN
# 365     37.2500
# 366    135.2500
# 367         NaN
# 368         NaN
# 369     93.3000
# 370     80.4417
# 371     24.4958
# 372     27.0500
# 373    157.6333
# 374     24.0750
# 375         NaN
# 376     29.2500
# 377    238.5000
# 378     24.0125
# 379     26.7750
# 380    269.5250
# 381     16.7417
# 382     39.9250
# 383     87.0000
# 384         NaN
# 385     91.5000
# 386     47.9000
# 387     49.0000
# 388         NaN
# 389     29.0000
# 390    156.0000
# 391     28.7958
# 392     35.9250
# 393    136.2750
# 394     40.7000
# 395     29.7958
# 396     38.8542
# 397     72.0000
# 398     33.5000
# 399     40.6500
# 400     46.9250
# 401     34.0500
# 402     30.8250
# 403     43.8500
# 404     28.6625
# 405     55.0000
# 406     58.7500
# 407     21.7500
# 408     28.7750
# 409         NaN
# 410         NaN
# 411         NaN
# 412    123.0000
# 413         NaN
# 414     51.9250
# 415         NaN
# 416     66.5000
# 417     31.0000
# 418     43.0000
# 419     34.1500
# 420         NaN
# 421     28.7333
# 422     36.8750
# 423     42.4000
# 424     38.2125
# 425         NaN
# 426     54.0000
# 427     45.0000
# 428         NaN
# 429     40.0500
# 430     54.5500
# 431         NaN
# 432     68.0000
# 433     24.1250
# 434    105.9000
# 435    134.0000
# 436     55.3750
# 437     42.7500
# 438    327.0000
# 439     41.5000
# 440     71.2500
# 441     29.5000
# 442     32.7750
# 443     41.0000
# 444         NaN
# 445     85.8583
# 446     32.5000
# 447     60.5500
# 448     24.2583
# 449     82.5000
# 450     63.7500
# 451         NaN
# 452     57.7500
# 453    138.1042
# 454         NaN
# 455     36.8958
# 456     91.5500
# 457         NaN
# 458     60.5000
# 459         NaN
# 460     74.5500
# 461     42.0500
# 462     85.5000
# 463     61.0000
# 464         NaN
# 465     45.0500
# 466         NaN
# 467     82.5500
# 468         NaN
# 469     20.0083
# 470         NaN
# 471     46.6625
# 472     60.7500
# 473     36.7917
# 474     31.8375
# 475         NaN
# 476     55.0000
# 477     36.0458
# 478     29.5208
# 479     14.2875
# 480     55.9000
# 481         NaN
# 482     58.0500
# 483     72.5875
# 484    116.0792
# 485         NaN
# 486    125.0000
# 487     87.7000
# 488     38.0500
# 489     24.9000
# 490         NaN
# 491     28.2500
# 492     85.5000
# 493    120.5042
# 494     29.0500
# 495         NaN
# 496    132.2667
# 497         NaN
# 498    176.5500
# 499     31.7958
# 500     25.6625
# 501     28.7500
# 502         NaN
# 503     46.5875
# 504    102.5000
# 505    126.9000
# 506     59.0000
# 507         NaN
# 508     50.5250
# 509     82.4958
# 510     36.7500
# 511         NaN
# 512     62.2875
# 513    113.4000
# 514     31.4958
# 515     81.0208
# 516     44.5000
# 517         NaN
# 518     62.0000
# 519     39.8958
# 520    123.5000
# 521     29.8958
# 522         NaN
# 523    101.9792
# 524         NaN
# 525     48.2500
# 526     60.5000
# 527         NaN
# 528     46.9250
# 529     34.5000
# 530     28.0000
# 531         NaN
# 532     24.2292
# 533         NaN
# 534     38.6625
# 535     33.2500
# 536     71.5500
# 537    136.4250
# 538         NaN
# 539     71.5000
# 540    107.0000
# 541     40.2750
# 542     42.2750
# 543     58.0000
# 544    156.4250
# 545     90.0000
# 546     45.0000
# 547         NaN
# 548     53.5250
# 549     44.7500
# 550    127.8833
# 551     53.0000
# 552         NaN
# 553     29.2250
# 554     29.7750
# 555     88.5500
# 556     87.6000
# 557         NaN
# 558    118.6500
# 559     53.4000
# 560         NaN
# 561     47.8958
# 562     41.5000
# 563         NaN
# 564         NaN
# 565     48.1500
# 566     26.8958
# 567     50.0750
# 568         NaN
# 569     39.8542
# 570     72.5000
# 571    104.4792
# 572     62.3875
# 573         NaN
# 574     24.0500
# 575     33.5000
# 576     47.0000
# 577     94.9000
# 578         NaN
# 579     39.9250
# 580     55.0000
# 581    149.8833
# 582     80.0000
# 583     76.1250
# 584         NaN
# 585     97.6500
# 586     62.0000
# 587    139.2000
# 588     30.0500
# 589         NaN
# 590     42.1250
# 591    130.2667
# 592     54.2500
# 593         NaN
# 594     63.0000
# 595     60.1500
# 596         NaN
# 597     49.0000
# 598         NaN
# 599    105.9292
# 600     51.0000
# 601         NaN
# 602         NaN
# 603     52.0500
# 604     61.5500
# 605     51.5500
# 606     37.8958
# 607     57.5000
# 608     63.5792
# 609    193.4625
# 610     70.2750
# 611         NaN
# 612         NaN
# 613         NaN
# 614     43.0500
# 615     89.0000
# 616     48.4000
# 617     42.1000
# 618     43.0000
# 619     36.5000
# 620     41.4542
# 621     94.5542
# 622     35.7417
# 623     28.8542
# 624     37.1000
# 625     93.3208
# 626     69.3500
# 627     98.9583
# 628     33.8958
# 629         NaN
# 630    110.0000
# 631     58.0542
# 632     62.5000
# 633         NaN
# 634     36.9000
# 635     41.0000
# 636     39.9250
# 637     57.2500
# 638     80.6875
# 639         NaN
# 640     27.8542
# 641     93.3000
# 642     29.9000
# 643         NaN
# 644     20.0083
# 645    124.7292
# 646     26.8958
# 647     91.5000
# 648         NaN
# 649     30.5500
# 650         NaN
# 651     41.0000
# 652     29.4333
# 653         NaN
# 654     24.7500
# 655     97.5000
# 656         NaN
# 657     47.5000
# 658     36.0000
# 659    171.2750
# 660    183.6500
# 661     47.2250
# 662     72.5875
# 663     43.4958
# 664     27.9250
# 665    105.5000
# 666     38.0000
# 667         NaN
# 668     51.0500
# 669         NaN
# 670     79.0000
# 671     83.0000
# 672     80.5000
# 673     44.0000
# 674         NaN
# 675     25.7750
# 676     32.5500
# 677     27.8417
# 678     89.9000
# 679    548.3292
# 680         NaN
# 681    103.7292
# 682     29.2250
# 683     60.9000
# 684     99.0000
# 685     66.5792
# 686     53.6875
# 687     29.1708
# 688     25.7958
# 689    226.3375
# 690     88.0000
# 691     17.4167
# 692         NaN
# 693     32.2250
# 694     86.5500
# 695     65.5000
# 696     52.0500
# 697         NaN
# 698    159.8833
# 699     49.6500
# 700    245.5250
# 701     61.2875
# 702     32.4542
# 703     32.7417
# 704     33.8542
# 705     65.0000
# 706     58.5000
# 707     68.2875
# 708    173.5500
# 709         NaN
# 710     73.5042
# 711         NaN
# 712    100.0000
# 713     38.4833
# 714     65.0000
# 715     26.6500
# 716    265.5250
# 717     37.5000
# 718         NaN
# 719     40.7750
# 720     39.0000
# 721     24.0542
# 722     47.0000
# 723     63.0000
# 724     80.1000
# 725     28.6625
# 726     51.0000
# 727         NaN
# 728     51.0000
# 729     32.9250
# 730    240.3375
# 731     29.7875
# 732         NaN
# 733     36.0000
# 734     36.0000
# 735     44.6000
# 736     82.3750
# 737    547.3292
# 738         NaN
# 739         NaN
# 740         NaN
# 741    114.8500
# 742    283.3750
# 743     40.1000
# 744     38.9250
# 745    141.0000
# 746     36.2500
# 747     43.0000
# 748     72.1000
# 749     38.7500
# 750     27.0000
# 751     18.4750
# 752     42.5000
# 753     30.8958
# 754    113.0000
# 755     15.1700
# 756     35.7958
# 757     29.5000
# 758     42.0500
# 759    119.5000
# 760         NaN
# 761     48.1250
# 762     27.2292
# 763    156.0000
# 764     23.7750
# 765    128.9583
# 766         NaN
# 767     38.2500
# 768         NaN
# 769     40.3625
# 770     33.5000
# 771     55.8542
# 772     67.5000
# 773         NaN
# 774     77.0000
# 775     25.7500
# 776         NaN
# 777     17.4750
# 778         NaN
# 779    254.3375
# 780     20.2292
# 781     74.0000
# 782     59.0000
# 783         NaN
# 784     32.0500
# 785     32.2500
# 786     25.4958
# 787     37.1250
# 788     21.5750
# 789    125.2000
# 790         NaN
# 791     42.0000
# 792         NaN
# 793         NaN
# 794     32.8958
# 795     52.0000
# 796     74.9292
# 797     39.6833
# 798     37.2292
# 799     54.1500
# 800     47.0000
# 801     57.2500
# 802    131.0000
# 803      8.9367
# 804     33.9750
# 805     38.7750
# 806     39.0000
# 807     25.7750
# 808     52.0000
# 809     86.1000
# 810     33.8875
# 811     63.1500
# 812     45.5000
# 813     37.2750
# 814     38.5500
# 815         NaN
# 816     30.9250
# 817     68.0042
# 818     49.4500
# 819     37.9000
# 820    145.5000
# 821     35.6625
# 822     38.0000
# 823     39.4750
# 824     41.6875
# 825         NaN
# 826         NaN
# 827     38.0042
# 828         NaN
# 829    142.0000
# 830     29.4542
# 831     19.5800
# 832         NaN
# 833     30.8542
# 834     26.3000
# 835    122.1583
# 836     29.6625
# 837         NaN
# 838     88.4958
# 839         NaN
# 840     27.9250
# 841     26.5000
# 842     61.0000
# 843     40.9375
# 844     25.6625
# 845     49.5500
# 846         NaN
# 847     42.8958
# 848     61.0000
# 849         NaN
# 850     35.2750
# 851     81.7750
# 852     24.2458
# 853     55.4000
# 854     70.0000
# 855     27.3500
# 856    209.8667
# 857     77.5500
# 858     43.2583
# 859         NaN
# 860     55.1083
# 861     32.5000
# 862     73.9292
# 863         NaN
# 849    Goldenberg, Mrs. Samuel L (Edwiga Grabowska), ...
# 850        Andersson, Master. Sigvard Harald Elias, male
# 851                            Svensson, Mr. Johan, male
# 852                      Boulos, Miss. Nourelain, female
# 853                    Lines, Miss. Mary Conover, female
# 854    Carter, Mrs. Ernest Courtenay (Lilian Hughes),...
# 855                   Aks, Mrs. Sam (Leah Rosen), female
# 856    Wick, Mrs. George Dennick (Mary Hitchcock), fe...
# 857                         Daly, Mr. Peter Denis , male
# 858        Baclini, Mrs. Solomon (Latifa Qurban), female
# 859                               Razi, Mr. Raihed, male
# 860                        Hansen, Mr. Claus Peter, male
# 861                    Giles, Mr. Frederick Edward, male
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863            Sage, Miss. Dorothy Edith "Dolly", female
# 864                         Gill, Mr. John William, male
# 865                     Bystrom, Mrs. (Karolina), female
# 866                 Duran y More, Miss. Asuncion, female
# 867           Roebling, Mr. Washington Augustus II, male
# 868                    van Melkebeke, Mr. Philemon, male
# 869                Johnson, Master. Harold Theodor, male
# 870                              Balkic, Mr. Cerin, male
# 871    Beckwith, Mrs. Richard Leonard (Sallie Monypen...
# 872                       Carlsson, Mr. Frans Olof, male
# 873                    Vander Cruyssen, Mr. Victor, male
# 874        Abelson, Mrs. Samuel (Hannah Wizosky), female
# 875             Najib, Miss. Adele Kiamie "Jane", female
# 876                  Gustafsson, Mr. Alfred Ossian, male
# 877                           Petroff, Mr. Nedelio, male
# 878                             Laleff, Mr. Kristo, male
# 879    Potter, Mrs. Thomas Jr (Lily Alexenia Wilson),...
# 880    Shelley, Mrs. William (Imanita Parrish Hall), ...
# 881                             Markun, Mr. Johann, male
# 882                 Dahlberg, Miss. Gerda Ulrika, female
# 883                  Banfield, Mr. Frederick James, male
# 884                         Sutehall, Mr. Henry Jr, male
# 885         Rice, Mrs. William (Margaret Norton), female
# 886                          Montvila, Rev. Juozas, male
# 887                 Graham, Miss. Margaret Edith, female
# 888     Johnston, Miss. Catherine Helen "Carrie", female
# 889                          Behr, Mr. Karl Howell, male
# 890                            Dooley, Mr. Patrick, male
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Checking for Missing Values and dropping/replacing missing values

# %%
# How to check for missing values in columns

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# check which values are not missing
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# How to drop rows having missing value

df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
# df.dropna(how = 'all')

# %%
# How to ignore missing values from specific column/s

df.dropna(subset = ['Age'], )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %%
# df.dropna(subset = ['Age','Cabin'], how = 'all')

# %%
# How to ignore missing values from specific column

df[~df.Age.isnull()].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# How to replace missing values

df.Age.fillna(df['Age'].mean(),)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# #### Aggregating data using crosstab, groupby and pivot_table

# %% [markdown]
# **pd.crosstab()** - Compute a simple cross tabulation of two (or more) categorical variables. By default computes a frequency table of the categorical variables unless an array of values and an aggregation function are passed.

# %%
# How many passenger survived were male or female

# %%
pd.crosstab(df['Survived'],df['Sex'])
#pd.crosstab(df['Survived'],df['Sex'], normalize = True, margins = True)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'index', margins = True)
# Out:
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713
# All       0.352413  0.647587

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'columns', margins = True)
# Out:
# Sex         female      male       All
# Survived
# 0         0.257962  0.811092  0.616162
# 1         0.742038  0.188908  0.383838

# %%
#pd.crosstab(df['Survived'],df['Sex'],values = df['Age'],aggfunc = 'mean')

# %% [markdown]
# A **groupby** operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# What is the average age of the passengers who survived and who did not

# %%
#df.groupby('Survived')['Age'].agg(['count','min','max','mean','median'])

# %%
# What is the average age and Fare of the passengers who survived and who did not

#df.groupby('Survived')[['Age','Fare']].mean()

# %%
#df.groupby('Survived').mean()

# %%
# What is the average age and median of Fare of the passengers who survived and who did not

#df.groupby('Survived').agg({'Age':'mean','Fare':'median'})

# %%
df.groupby('Survived').agg({'Age':'mean','Fare':'median','Pclass':'unique'})
# Out:
#                 Age  Fare     Pclass
# Survived
# 0         30.626179  10.5  [3, 1, 2]
# 1         28.343690  26.0  [1, 3, 2]

# %%
# How many passenger survived were male or female

df.groupby(['Survived','Sex']).size()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# dtype: int64

# %%
# What is the average age of passengers gender wise who survived and who did not

df.groupby(['Survived','Sex'])['Age'].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %%
df.groupby(['Survived','Sex'])['Age'].mean().unstack()
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %%
df.groupby(['Survived','Sex'])['Age'].mean().reset_index()
# Out:
#    Survived     Sex        Age
# 0         0  female  25.046875
# 1         0    male  31.618056
# 2         1  female  28.847716
# 3         1    male  27.276022

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Exercise Question

#People boarded from which port survived the most

# %%
#How many people survived if Fare is less than 20

# %% [markdown]
# #### Pivot Table

# %%
# What is the average age of passengers who survived and who did not

df.pivot_table(index='Survived', values = 'Age', aggfunc = 'mean')
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
# How many passenger survived were male or female

df.pivot_table(index='Survived', values = 'Sex', aggfunc = 'count')
# Out:
#           Sex
# Survived
# 0         549
# 1         342

# %%
# What is the average age of passengers gender wise who survived and who did not

df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean')
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %% [markdown]
# #### Reshaping dataframe using melt

# %%
df2 = df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean').reset_index()
df2
# Out:
# Sex  Survived     female       male
# 0           0  25.046875  31.618056
# 1           1  28.847716  27.276022

# %%
df2.melt( ,value_name  = 'Mean_Age')
# Out:
#       Sex   Mean_Age
# 0  female  25.046875
# 1  female  28.847716
# 2    male  31.618056
# 3    male  27.276022

# %% [markdown]
# ### Merge/Joins

# %% [markdown]
# There are actually four types of joins supported by the Pandas `merge` function. Here's how they are described by the documentation:
#
# - **inner:** use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys
# - **outer:** use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically
# - **left:** use only keys from left frame, similar to a SQL left outer join; preserve key order
# - **right:** use only keys from right frame, similar to a SQL right outer join; preserve key order
#
# The default is the "inner join", which was used when creating the movie_ratings DataFrame.
#
# It's easiest to understand the different types by looking at some simple examples:

# %% [markdown]
# #### Example DataFrames A and B

# %%
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# ### Inner join
#
# Only include observations found in both A and B:

# %%
pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# ### Outer join
#
# Include observations found in either A or B:

# %%
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# ### Left join
#
# Include all observations found in A:

# %%
pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# ### Right join
#
# Include all observations found in B:

# %%
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# #### Merging/Joining two data frames

# %%
df1 = pd.read_csv('customer_db.txt')
df2 = pd.read_csv('orders.txt')

# %%
df1
# Out:
#    customer_id first_name   last_name                email  \
# 0            1     George  Washington  gwashington@usa.gov
# 1            2       John       Adams       jadams@usa.gov
# 2            3     Thomas   Jefferson   tjefferson@usa.gov
# 3            4      James     Madison     jmadison@usa.gov
# 4            5      James      Monroe      jmonroe@usa.gov
#
#                      address             city state  zipcode
# 0         3200 Mt Vernon Hwy     Mount Vernon    VA    22121
# 1            1250 Hancock St           Quincy    MA     2169
# 2  931 Thomas Jefferson Pkwy  Charlottesville    VA    22902
# 3     11350 Constitution Hwy           Orange    VA    22960
# 4  2050 James Monroe Parkway  Charlottesville    VA    22902

# %%
df2
# Out:
#    order_id  order_date   amount  customer_id
# 0         1  07/04/1776  $234.56            1
# 1         2  03/14/1760   $78.50            3
# 2         3  05/23/1784  $124.00            2
# 3         4  09/03/1790   $65.50            3
# 4         5  07/21/1795   $25.50           10
# 5         6  11/27/1787   $14.40            9

# %%
pd.merge(df2,df1, on = 'customer_id', how = 'outer')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0       1.0  07/04/1776  $234.56            1     George  Washington
# 1       2.0  03/14/1760   $78.50            3     Thomas   Jefferson
# 2       4.0  09/03/1790   $65.50            3     Thomas   Jefferson
# 3       3.0  05/23/1784  $124.00            2       John       Adams
# 4       5.0  07/21/1795   $25.50           10        NaN         NaN
# 5       6.0  11/27/1787   $14.40            9        NaN         NaN
# 6       NaN         NaN      NaN            4      James     Madison
# 7       NaN         NaN      NaN            5      James      Monroe
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 3       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
# 6     jmadison@usa.gov     11350 Constitution Hwy           Orange    VA
# 7      jmonroe@usa.gov  2050 James Monroe Parkway  Charlottesville    VA
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2  22902.0
# 3   2169.0
# 4      NaN
# 5      NaN
# 6  22960.0
# 7  22902.0

# %%
df2.merge(df1, on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0         1  07/04/1776  $234.56            1     George  Washington
# 1         2  03/14/1760   $78.50            3     Thomas   Jefferson
# 2         3  05/23/1784  $124.00            2       John       Adams
# 3         4  09/03/1790   $65.50            3     Thomas   Jefferson
# 4         5  07/21/1795   $25.50           10        NaN         NaN
# 5         6  11/27/1787   $14.40            9        NaN         NaN
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 3   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2   2169.0
# 3  22902.0
# 4      NaN
# 5      NaN

# %%
df2.rename(columns = {'customer_id':'customer'}, inplace=True)

# %%
df2.head()
# Out:
#    order_id  order_date   amount  customer
# 0         1  07/04/1776  $234.56         1
# 1         2  03/14/1760   $78.50         3
# 2         3  05/23/1784  $124.00         2
# 3         4  09/03/1790   $65.50         3
# 4         5  07/21/1795   $25.50        10

# %%
df2.merge(df1, left_on = 'customer', right_on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer  customer_id first_name  \
# 0         1  07/04/1776  $234.56         1          1.0     George
# 1         2  03/14/1760   $78.50         3          3.0     Thomas
# 2         3  05/23/1784  $124.00         2          2.0       John
# 3         4  09/03/1790   $65.50         3          3.0     Thomas
# 4         5  07/21/1795   $25.50        10          NaN        NaN
# 5         6  11/27/1787   $14.40         9          NaN        NaN
#
#     last_name                email                    address  \
# 0  Washington  gwashington@usa.gov         3200 Mt Vernon Hwy
# 1   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 2       Adams       jadams@usa.gov            1250 Hancock St
# 3   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 4         NaN                  NaN                        NaN
# 5         NaN                  NaN                        NaN
#
#               city state  zipcode
# 0     Mount Vernon    VA  22121.0
# 1  Charlottesville    VA  22902.0
# 2           Quincy    MA   2169.0
# 3  Charlottesville    VA  22902.0
# 4              NaN   NaN      NaN
# 5              NaN   NaN      NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Transforming Columns using map, apply and applymap

# %%
def addition(a):
    return a+4

# %%
add = lambda x : x+2

# %%
add(2)
# Out:
# 4

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.Age = df.Age.map(lambda x: x+4)

# %%
df.Age = df.Age.map(addition)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  30.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  46.0      1
# 2                             Heikkinen, Miss. Laina  female  34.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  43.0      1
# 4                           Allen, Mr. William Henry    male  43.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.apply(lambda x: x.as_type).head()

# %%
df[['Age','Fare']].applymap(lambda x : x+2).head()
# Out:
#     Age     Fare
# 0  24.0   9.2500
# 1  40.0  73.2833
# 2  28.0   9.9250
# 3  37.0  55.1000
# 4  37.0  10.0500

# %% [markdown]
# #### How to remove duplicate rows

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(subset =)

# %% [markdown]
# #### Working with Date and time

# %% [markdown]
# #### Exporting Output

# %%
#Writing to a csv file

df.to_csv(filename,)

# %% [markdown]
# #### Reading and writing from/to excel files

# %%
pd.read_excel()

# %% [markdown]
# #### Checking for Missing Values and dropping/replacing missing values

# %%
# How to check for missing values in columns

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# check which values are not missing
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# How to drop rows having missing value

df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
# df.dropna(how = 'all')

# %%
# How to ignore missing values from specific column/s

df.dropna(subset = ['Age'], )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %%
# df.dropna(subset = ['Age','Cabin'], how = 'all')

# %%
# How to ignore missing values from specific column

df[~df.Age.isnull()].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# How to replace missing values

df.Age.fillna(df['Age'].mean(),)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# #### Aggregating data using crosstab, groupby and pivot_table

# %% [markdown]
# **pd.crosstab()** - Compute a simple cross tabulation of two (or more) categorical variables. By default computes a frequency table of the categorical variables unless an array of values and an aggregation function are passed.

# %%
# How many passenger survived were male or female

# %%
pd.crosstab(df['Survived'],df['Sex'])
#pd.crosstab(df['Survived'],df['Sex'], normalize = True, margins = True)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'index', margins = True)
# Out:
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713
# All       0.352413  0.647587

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'columns', margins = True)
# Out:
# Sex         female      male       All
# Survived
# 0         0.257962  0.811092  0.616162
# 1         0.742038  0.188908  0.383838

# %%
#pd.crosstab(df['Survived'],df['Sex'],values = df['Age'],aggfunc = 'mean')

# %% [markdown]
# A **groupby** operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# What is the average age of the passengers who survived and who did not

# %%
#df.groupby('Survived')['Age'].agg(['count','min','max','mean','median'])

# %%
# What is the average age and Fare of the passengers who survived and who did not

#df.groupby('Survived')[['Age','Fare']].mean()

# %%
#df.groupby('Survived').mean()

# %%
# What is the average age and median of Fare of the passengers who survived and who did not

#df.groupby('Survived').agg({'Age':'mean','Fare':'median'})

# %%
df.groupby('Survived').agg({'Age':'mean','Fare':'median','Pclass':'unique'})
# Out:
#                 Age  Fare     Pclass
# Survived
# 0         30.626179  10.5  [3, 1, 2]
# 1         28.343690  26.0  [1, 3, 2]

# %%
# How many passenger survived were male or female

df.groupby(['Survived','Sex']).size()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# dtype: int64

# %%
# What is the average age of passengers gender wise who survived and who did not

df.groupby(['Survived','Sex'])['Age'].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %%
df.groupby(['Survived','Sex'])['Age'].mean().unstack()
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %%
df.groupby(['Survived','Sex'])['Age'].mean().reset_index()
# Out:
#    Survived     Sex        Age
# 0         0  female  25.046875
# 1         0    male  31.618056
# 2         1  female  28.847716
# 3         1    male  27.276022

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Exercise Question

#People boarded from which port survived the most

# %%
#How many people survived if Fare is less than 20

# %% [markdown]
# #### Pivot Table

# %%
# What is the average age of passengers who survived and who did not

df.pivot_table(index='Survived', values = 'Age', aggfunc = 'mean')
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
# How many passenger survived were male or female

df.pivot_table(index='Survived', values = 'Sex', aggfunc = 'count')
# Out:
#           Sex
# Survived
# 0         549
# 1         342

# %%
# What is the average age of passengers gender wise who survived and who did not

df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean')
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %% [markdown]
# #### Reshaping dataframe using melt

# %%
df2 = df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean').reset_index()
df2
# Out:
# Sex  Survived     female       male
# 0           0  25.046875  31.618056
# 1           1  28.847716  27.276022

# %%
df2.melt( ,value_name  = 'Mean_Age')
# Out:
#       Sex   Mean_Age
# 0  female  25.046875
# 1  female  28.847716
# 2    male  31.618056
# 3    male  27.276022

# %% [markdown]
# ### Merge/Joins

# %% [markdown]
# There are actually four types of joins supported by the Pandas `merge` function. Here's how they are described by the documentation:
#
# - **inner:** use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys
# - **outer:** use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically
# - **left:** use only keys from left frame, similar to a SQL left outer join; preserve key order
# - **right:** use only keys from right frame, similar to a SQL right outer join; preserve key order
#
# The default is the "inner join", which was used when creating the movie_ratings DataFrame.
#
# It's easiest to understand the different types by looking at some simple examples:

# %% [markdown]
# #### Example DataFrames A and B

# %%
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# ### Inner join
#
# Only include observations found in both A and B:

# %%
pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# ### Outer join
#
# Include observations found in either A or B:

# %%
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# ### Left join
#
# Include all observations found in A:

# %%
pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# ### Right join
#
# Include all observations found in B:

# %%
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# #### Merging/Joining two data frames

# %%
df1 = pd.read_csv('customer_db.txt')
df2 = pd.read_csv('orders.txt')

# %%
df1
# Out:
#    customer_id first_name   last_name                email  \
# 0            1     George  Washington  gwashington@usa.gov
# 1            2       John       Adams       jadams@usa.gov
# 2            3     Thomas   Jefferson   tjefferson@usa.gov
# 3            4      James     Madison     jmadison@usa.gov
# 4            5      James      Monroe      jmonroe@usa.gov
#
#                      address             city state  zipcode
# 0         3200 Mt Vernon Hwy     Mount Vernon    VA    22121
# 1            1250 Hancock St           Quincy    MA     2169
# 2  931 Thomas Jefferson Pkwy  Charlottesville    VA    22902
# 3     11350 Constitution Hwy           Orange    VA    22960
# 4  2050 James Monroe Parkway  Charlottesville    VA    22902

# %%
df2
# Out:
#    order_id  order_date   amount  customer_id
# 0         1  07/04/1776  $234.56            1
# 1         2  03/14/1760   $78.50            3
# 2         3  05/23/1784  $124.00            2
# 3         4  09/03/1790   $65.50            3
# 4         5  07/21/1795   $25.50           10
# 5         6  11/27/1787   $14.40            9

# %%
pd.merge(df2,df1, on = 'customer_id', how = 'outer')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0       1.0  07/04/1776  $234.56            1     George  Washington
# 1       2.0  03/14/1760   $78.50            3     Thomas   Jefferson
# 2       4.0  09/03/1790   $65.50            3     Thomas   Jefferson
# 3       3.0  05/23/1784  $124.00            2       John       Adams
# 4       5.0  07/21/1795   $25.50           10        NaN         NaN
# 5       6.0  11/27/1787   $14.40            9        NaN         NaN
# 6       NaN         NaN      NaN            4      James     Madison
# 7       NaN         NaN      NaN            5      James      Monroe
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 3       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
# 6     jmadison@usa.gov     11350 Constitution Hwy           Orange    VA
# 7      jmonroe@usa.gov  2050 James Monroe Parkway  Charlottesville    VA
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2  22902.0
# 3   2169.0
# 4      NaN
# 5      NaN
# 6  22960.0
# 7  22902.0

# %%
df2.merge(df1, on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0         1  07/04/1776  $234.56            1     George  Washington
# 1         2  03/14/1760   $78.50            3     Thomas   Jefferson
# 2         3  05/23/1784  $124.00            2       John       Adams
# 3         4  09/03/1790   $65.50            3     Thomas   Jefferson
# 4         5  07/21/1795   $25.50           10        NaN         NaN
# 5         6  11/27/1787   $14.40            9        NaN         NaN
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 3   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2   2169.0
# 3  22902.0
# 4      NaN
# 5      NaN

# %%
df2.rename(columns = {'customer_id':'customer'}, inplace=True)

# %%
df2.head()
# Out:
#    order_id  order_date   amount  customer
# 0         1  07/04/1776  $234.56         1
# 1         2  03/14/1760   $78.50         3
# 2         3  05/23/1784  $124.00         2
# 3         4  09/03/1790   $65.50         3
# 4         5  07/21/1795   $25.50        10

# %%
df2.merge(df1, left_on = 'customer', right_on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer  customer_id first_name  \
# 0         1  07/04/1776  $234.56         1          1.0     George
# 1         2  03/14/1760   $78.50         3          3.0     Thomas
# 2         3  05/23/1784  $124.00         2          2.0       John
# 3         4  09/03/1790   $65.50         3          3.0     Thomas
# 4         5  07/21/1795   $25.50        10          NaN        NaN
# 5         6  11/27/1787   $14.40         9          NaN        NaN
#
#     last_name                email                    address  \
# 0  Washington  gwashington@usa.gov         3200 Mt Vernon Hwy
# 1   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 2       Adams       jadams@usa.gov            1250 Hancock St
# 3   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 4         NaN                  NaN                        NaN
# 5         NaN                  NaN                        NaN
#
#               city state  zipcode
# 0     Mount Vernon    VA  22121.0
# 1  Charlottesville    VA  22902.0
# 2           Quincy    MA   2169.0
# 3  Charlottesville    VA  22902.0
# 4              NaN   NaN      NaN
# 5              NaN   NaN      NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Transforming Columns using map, apply and applymap

# %%
def addition(a):
    return a+4

# %%
add = lambda x : x+2

# %%
add(2)
# Out:
# 4

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.Age = df.Age.map(lambda x: x+4)

# %%
df.Age = df.Age.map(addition)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  30.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  46.0      1
# 2                             Heikkinen, Miss. Laina  female  34.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  43.0      1
# 4                           Allen, Mr. William Henry    male  43.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.apply(lambda x: x.as_type).head()

# %%
df[['Age','Fare']].applymap(lambda x : x+2).head()
# Out:
#     Age     Fare
# 0  24.0   9.2500
# 1  40.0  73.2833
# 2  28.0   9.9250
# 3  37.0  55.1000
# 4  37.0  10.0500

# %% [markdown]
# #### How to remove duplicate rows

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(subset =)

# %% [markdown]
# #### Working with Date and time

# %% [markdown]
# #### Exporting Output

# %%
#Writing to a csv file

df.to_csv(filename,)

# %% [markdown]
# #### Reading and writing from/to excel files

# %%
pd.read_excel()

# %% [markdown]
# #### Checking for Missing Values and dropping/replacing missing values

# %%
# How to check for missing values in columns

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# check which values are not missing
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# How to drop rows having missing value

df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
# df.dropna(how = 'all')

# %%
# How to ignore missing values from specific column/s

df.dropna(subset = ['Age'], )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %%
# df.dropna(subset = ['Age','Cabin'], how = 'all')

# %%
# How to ignore missing values from specific column

df[~df.Age.isnull()].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# How to replace missing values

df.Age.fillna(df['Age'].mean(),)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# #### Aggregating data using crosstab, groupby and pivot_table

# %% [markdown]
# **pd.crosstab()** - Compute a simple cross tabulation of two (or more) categorical variables. By default computes a frequency table of the categorical variables unless an array of values and an aggregation function are passed.

# %%
# How many passenger survived were male or female

# %%
pd.crosstab(df['Survived'],df['Sex'])
#pd.crosstab(df['Survived'],df['Sex'], normalize = True, margins = True)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'index', margins = True)
# Out:
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713
# All       0.352413  0.647587

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'columns', margins = True)
# Out:
# Sex         female      male       All
# Survived
# 0         0.257962  0.811092  0.616162
# 1         0.742038  0.188908  0.383838

# %%
#pd.crosstab(df['Survived'],df['Sex'],values = df['Age'],aggfunc = 'mean')

# %% [markdown]
# A **groupby** operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# What is the average age of the passengers who survived and who did not

# %%
#df.groupby('Survived')['Age'].agg(['count','min','max','mean','median'])

# %%
# What is the average age and Fare of the passengers who survived and who did not

#df.groupby('Survived')[['Age','Fare']].mean()

# %%
#df.groupby('Survived').mean()

# %%
# What is the average age and median of Fare of the passengers who survived and who did not

#df.groupby('Survived').agg({'Age':'mean','Fare':'median'})

# %%
df.groupby('Survived').agg({'Age':'mean','Fare':'median','Pclass':'unique'})
# Out:
#                 Age  Fare     Pclass
# Survived
# 0         30.626179  10.5  [3, 1, 2]
# 1         28.343690  26.0  [1, 3, 2]

# %%
# How many passenger survived were male or female

df.groupby(['Survived','Sex']).size()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# dtype: int64

# %%
# What is the average age of passengers gender wise who survived and who did not

df.groupby(['Survived','Sex'])['Age'].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %%
df.groupby(['Survived','Sex'])['Age'].mean().unstack()
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %%
df.groupby(['Survived','Sex'])['Age'].mean().reset_index()
# Out:
#    Survived     Sex        Age
# 0         0  female  25.046875
# 1         0    male  31.618056
# 2         1  female  28.847716
# 3         1    male  27.276022

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Exercise Question

#People boarded from which port survived the most

# %%
#How many people survived if Fare is less than 20

# %% [markdown]
# #### Pivot Table

# %%
# What is the average age of passengers who survived and who did not

df.pivot_table(index='Survived', values = 'Age', aggfunc = 'mean')
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
# How many passenger survived were male or female

df.pivot_table(index='Survived', values = 'Sex', aggfunc = 'count')
# Out:
#           Sex
# Survived
# 0         549
# 1         342

# %%
# What is the average age of passengers gender wise who survived and who did not

df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean')
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %% [markdown]
# #### Reshaping dataframe using melt

# %%
df2 = df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean').reset_index()
df2
# Out:
# Sex  Survived     female       male
# 0           0  25.046875  31.618056
# 1           1  28.847716  27.276022

# %%
df2.melt( ,value_name  = 'Mean_Age')
# Out:
#       Sex   Mean_Age
# 0  female  25.046875
# 1  female  28.847716
# 2    male  31.618056
# 3    male  27.276022

# %% [markdown]
# ### Merge/Joins

# %% [markdown]
# There are actually four types of joins supported by the Pandas `merge` function. Here's how they are described by the documentation:
#
# - **inner:** use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys
# - **outer:** use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically
# - **left:** use only keys from left frame, similar to a SQL left outer join; preserve key order
# - **right:** use only keys from right frame, similar to a SQL right outer join; preserve key order
#
# The default is the "inner join", which was used when creating the movie_ratings DataFrame.
#
# It's easiest to understand the different types by looking at some simple examples:

# %% [markdown]
# #### Example DataFrames A and B

# %%
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# ### Inner join
#
# Only include observations found in both A and B:

# %%
pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# ### Outer join
#
# Include observations found in either A or B:

# %%
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# ### Left join
#
# Include all observations found in A:

# %%
pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# ### Right join
#
# Include all observations found in B:

# %%
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# #### Merging/Joining two data frames

# %%
df1 = pd.read_csv('customer_db.txt')
df2 = pd.read_csv('orders.txt')

# %%
df1
# Out:
#    customer_id first_name   last_name                email  \
# 0            1     George  Washington  gwashington@usa.gov
# 1            2       John       Adams       jadams@usa.gov
# 2            3     Thomas   Jefferson   tjefferson@usa.gov
# 3            4      James     Madison     jmadison@usa.gov
# 4            5      James      Monroe      jmonroe@usa.gov
#
#                      address             city state  zipcode
# 0         3200 Mt Vernon Hwy     Mount Vernon    VA    22121
# 1            1250 Hancock St           Quincy    MA     2169
# 2  931 Thomas Jefferson Pkwy  Charlottesville    VA    22902
# 3     11350 Constitution Hwy           Orange    VA    22960
# 4  2050 James Monroe Parkway  Charlottesville    VA    22902

# %%
df2
# Out:
#    order_id  order_date   amount  customer_id
# 0         1  07/04/1776  $234.56            1
# 1         2  03/14/1760   $78.50            3
# 2         3  05/23/1784  $124.00            2
# 3         4  09/03/1790   $65.50            3
# 4         5  07/21/1795   $25.50           10
# 5         6  11/27/1787   $14.40            9

# %%
pd.merge(df2,df1, on = 'customer_id', how = 'outer')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0       1.0  07/04/1776  $234.56            1     George  Washington
# 1       2.0  03/14/1760   $78.50            3     Thomas   Jefferson
# 2       4.0  09/03/1790   $65.50            3     Thomas   Jefferson
# 3       3.0  05/23/1784  $124.00            2       John       Adams
# 4       5.0  07/21/1795   $25.50           10        NaN         NaN
# 5       6.0  11/27/1787   $14.40            9        NaN         NaN
# 6       NaN         NaN      NaN            4      James     Madison
# 7       NaN         NaN      NaN            5      James      Monroe
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 3       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
# 6     jmadison@usa.gov     11350 Constitution Hwy           Orange    VA
# 7      jmonroe@usa.gov  2050 James Monroe Parkway  Charlottesville    VA
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2  22902.0
# 3   2169.0
# 4      NaN
# 5      NaN
# 6  22960.0
# 7  22902.0

# %%
df2.merge(df1, on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0         1  07/04/1776  $234.56            1     George  Washington
# 1         2  03/14/1760   $78.50            3     Thomas   Jefferson
# 2         3  05/23/1784  $124.00            2       John       Adams
# 3         4  09/03/1790   $65.50            3     Thomas   Jefferson
# 4         5  07/21/1795   $25.50           10        NaN         NaN
# 5         6  11/27/1787   $14.40            9        NaN         NaN
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 3   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2   2169.0
# 3  22902.0
# 4      NaN
# 5      NaN

# %%
df2.rename(columns = {'customer_id':'customer'}, inplace=True)

# %%
df2.head()
# Out:
#    order_id  order_date   amount  customer
# 0         1  07/04/1776  $234.56         1
# 1         2  03/14/1760   $78.50         3
# 2         3  05/23/1784  $124.00         2
# 3         4  09/03/1790   $65.50         3
# 4         5  07/21/1795   $25.50        10

# %%
df2.merge(df1, left_on = 'customer', right_on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer  customer_id first_name  \
# 0         1  07/04/1776  $234.56         1          1.0     George
# 1         2  03/14/1760   $78.50         3          3.0     Thomas
# 2         3  05/23/1784  $124.00         2          2.0       John
# 3         4  09/03/1790   $65.50         3          3.0     Thomas
# 4         5  07/21/1795   $25.50        10          NaN        NaN
# 5         6  11/27/1787   $14.40         9          NaN        NaN
#
#     last_name                email                    address  \
# 0  Washington  gwashington@usa.gov         3200 Mt Vernon Hwy
# 1   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 2       Adams       jadams@usa.gov            1250 Hancock St
# 3   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 4         NaN                  NaN                        NaN
# 5         NaN                  NaN                        NaN
#
#               city state  zipcode
# 0     Mount Vernon    VA  22121.0
# 1  Charlottesville    VA  22902.0
# 2           Quincy    MA   2169.0
# 3  Charlottesville    VA  22902.0
# 4              NaN   NaN      NaN
# 5              NaN   NaN      NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Transforming Columns using map, apply and applymap

# %%
def addition(a):
    return a+4

# %%
add = lambda x : x+2

# %%
add(2)
# Out:
# 4

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.Age = df.Age.map(lambda x: x+4)

# %%
df.Age = df.Age.map(addition)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  30.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  46.0      1
# 2                             Heikkinen, Miss. Laina  female  34.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  43.0      1
# 4                           Allen, Mr. William Henry    male  43.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.apply(lambda x: x.as_type).head()

# %%
df[['Age','Fare']].applymap(lambda x : x+2).head()
# Out:
#     Age     Fare
# 0  24.0   9.2500
# 1  40.0  73.2833
# 2  28.0   9.9250
# 3  37.0  55.1000
# 4  37.0  10.0500

# %% [markdown]
# #### How to remove duplicate rows

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(subset =)

# %% [markdown]
# #### Working with Date and time

# %% [markdown]
# #### Exporting Output

# %%
#Writing to a csv file

df.to_csv(filename,)

# %% [markdown]
# #### Reading and writing from/to excel files

# %%
pd.read_excel()

# %% [markdown]
# #### Checking for Missing Values and dropping/replacing missing values

# %%
# How to check for missing values in columns

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# check which values are not missing
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# How to drop rows having missing value

df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
# df.dropna(how = 'all')

# %%
# How to ignore missing values from specific column/s

df.dropna(subset = ['Age'], )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %%
# df.dropna(subset = ['Age','Cabin'], how = 'all')

# %%
# How to ignore missing values from specific column

df[~df.Age.isnull()].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# How to replace missing values

df.Age.fillna(df['Age'].mean(),)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# #### Aggregating data using crosstab, groupby and pivot_table

# %% [markdown]
# **pd.crosstab()** - Compute a simple cross tabulation of two (or more) categorical variables. By default computes a frequency table of the categorical variables unless an array of values and an aggregation function are passed.

# %%
# How many passenger survived were male or female

# %%
pd.crosstab(df['Survived'],df['Sex'])
#pd.crosstab(df['Survived'],df['Sex'], normalize = True, margins = True)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'index', margins = True)
# Out:
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713
# All       0.352413  0.647587

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize = 'columns', margins = True)
# Out:
# Sex         female      male       All
# Survived
# 0         0.257962  0.811092  0.616162
# 1         0.742038  0.188908  0.383838

# %%
#pd.crosstab(df['Survived'],df['Sex'],values = df['Age'],aggfunc = 'mean')

# %% [markdown]
# A **groupby** operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# What is the average age of the passengers who survived and who did not

# %%
#df.groupby('Survived')['Age'].agg(['count','min','max','mean','median'])

# %%
# What is the average age and Fare of the passengers who survived and who did not

#df.groupby('Survived')[['Age','Fare']].mean()

# %%
#df.groupby('Survived').mean()

# %%
# What is the average age and median of Fare of the passengers who survived and who did not

#df.groupby('Survived').agg({'Age':'mean','Fare':'median'})

# %%
df.groupby('Survived').agg({'Age':'mean','Fare':'median','Pclass':'unique'})
# Out:
#                 Age  Fare     Pclass
# Survived
# 0         30.626179  10.5  [3, 1, 2]
# 1         28.343690  26.0  [1, 3, 2]

# %%
# How many passenger survived were male or female

df.groupby(['Survived','Sex']).size()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# dtype: int64

# %%
# What is the average age of passengers gender wise who survived and who did not

df.groupby(['Survived','Sex'])['Age'].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %%
df.groupby(['Survived','Sex'])['Age'].mean().unstack()
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %%
df.groupby(['Survived','Sex'])['Age'].mean().reset_index()
# Out:
#    Survived     Sex        Age
# 0         0  female  25.046875
# 1         0    male  31.618056
# 2         1  female  28.847716
# 3         1    male  27.276022

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Exercise Question

#People boarded from which port survived the most

# %%
#How many people survived if Fare is less than 20

# %% [markdown]
# #### Pivot Table

# %%
# What is the average age of passengers who survived and who did not

df.pivot_table(index='Survived', values = 'Age', aggfunc = 'mean')
# Out:
#                 Age
# Survived
# 0         30.626179
# 1         28.343690

# %%
# How many passenger survived were male or female

df.pivot_table(index='Survived', values = 'Sex', aggfunc = 'count')
# Out:
#           Sex
# Survived
# 0         549
# 1         342

# %%
# What is the average age of passengers gender wise who survived and who did not

df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean')
# Out:
# Sex          female       male
# Survived
# 0         25.046875  31.618056
# 1         28.847716  27.276022

# %% [markdown]
# #### Reshaping dataframe using melt

# %%
df2 = df.pivot_table(index='Survived', columns = 'Sex', values = 'Age', aggfunc = 'mean').reset_index()
df2
# Out:
# Sex  Survived     female       male
# 0           0  25.046875  31.618056
# 1           1  28.847716  27.276022

# %%
df2.melt( ,value_name  = 'Mean_Age')
# Out:
#       Sex   Mean_Age
# 0  female  25.046875
# 1  female  28.847716
# 2    male  31.618056
# 3    male  27.276022

# %% [markdown]
# ### Merge/Joins

# %% [markdown]
# There are actually four types of joins supported by the Pandas `merge` function. Here's how they are described by the documentation:
#
# - **inner:** use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys
# - **outer:** use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically
# - **left:** use only keys from left frame, similar to a SQL left outer join; preserve key order
# - **right:** use only keys from right frame, similar to a SQL right outer join; preserve key order
#
# The default is the "inner join", which was used when creating the movie_ratings DataFrame.
#
# It's easiest to understand the different types by looking at some simple examples:

# %% [markdown]
# #### Example DataFrames A and B

# %%
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# ### Inner join
#
# Only include observations found in both A and B:

# %%
pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# ### Outer join
#
# Include observations found in either A or B:

# %%
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# ### Left join
#
# Include all observations found in A:

# %%
pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# ### Right join
#
# Include all observations found in B:

# %%
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# #### Merging/Joining two data frames

# %%
df1 = pd.read_csv('customer_db.txt')
df2 = pd.read_csv('orders.txt')

# %%
df1
# Out:
#    customer_id first_name   last_name                email  \
# 0            1     George  Washington  gwashington@usa.gov
# 1            2       John       Adams       jadams@usa.gov
# 2            3     Thomas   Jefferson   tjefferson@usa.gov
# 3            4      James     Madison     jmadison@usa.gov
# 4            5      James      Monroe      jmonroe@usa.gov
#
#                      address             city state  zipcode
# 0         3200 Mt Vernon Hwy     Mount Vernon    VA    22121
# 1            1250 Hancock St           Quincy    MA     2169
# 2  931 Thomas Jefferson Pkwy  Charlottesville    VA    22902
# 3     11350 Constitution Hwy           Orange    VA    22960
# 4  2050 James Monroe Parkway  Charlottesville    VA    22902

# %%
df2
# Out:
#    order_id  order_date   amount  customer_id
# 0         1  07/04/1776  $234.56            1
# 1         2  03/14/1760   $78.50            3
# 2         3  05/23/1784  $124.00            2
# 3         4  09/03/1790   $65.50            3
# 4         5  07/21/1795   $25.50           10
# 5         6  11/27/1787   $14.40            9

# %%
pd.merge(df2,df1, on = 'customer_id', how = 'outer')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0       1.0  07/04/1776  $234.56            1     George  Washington
# 1       2.0  03/14/1760   $78.50            3     Thomas   Jefferson
# 2       4.0  09/03/1790   $65.50            3     Thomas   Jefferson
# 3       3.0  05/23/1784  $124.00            2       John       Adams
# 4       5.0  07/21/1795   $25.50           10        NaN         NaN
# 5       6.0  11/27/1787   $14.40            9        NaN         NaN
# 6       NaN         NaN      NaN            4      James     Madison
# 7       NaN         NaN      NaN            5      James      Monroe
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 3       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
# 6     jmadison@usa.gov     11350 Constitution Hwy           Orange    VA
# 7      jmonroe@usa.gov  2050 James Monroe Parkway  Charlottesville    VA
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2  22902.0
# 3   2169.0
# 4      NaN
# 5      NaN
# 6  22960.0
# 7  22902.0

# %%
df2.merge(df1, on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer_id first_name   last_name  \
# 0         1  07/04/1776  $234.56            1     George  Washington
# 1         2  03/14/1760   $78.50            3     Thomas   Jefferson
# 2         3  05/23/1784  $124.00            2       John       Adams
# 3         4  09/03/1790   $65.50            3     Thomas   Jefferson
# 4         5  07/21/1795   $25.50           10        NaN         NaN
# 5         6  11/27/1787   $14.40            9        NaN         NaN
#
#                  email                    address             city state  \
# 0  gwashington@usa.gov         3200 Mt Vernon Hwy     Mount Vernon    VA
# 1   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 2       jadams@usa.gov            1250 Hancock St           Quincy    MA
# 3   tjefferson@usa.gov  931 Thomas Jefferson Pkwy  Charlottesville    VA
# 4                  NaN                        NaN              NaN   NaN
# 5                  NaN                        NaN              NaN   NaN
#
#    zipcode
# 0  22121.0
# 1  22902.0
# 2   2169.0
# 3  22902.0
# 4      NaN
# 5      NaN

# %%
df2.rename(columns = {'customer_id':'customer'}, inplace=True)

# %%
df2.head()
# Out:
#    order_id  order_date   amount  customer
# 0         1  07/04/1776  $234.56         1
# 1         2  03/14/1760   $78.50         3
# 2         3  05/23/1784  $124.00         2
# 3         4  09/03/1790   $65.50         3
# 4         5  07/21/1795   $25.50        10

# %%
df2.merge(df1, left_on = 'customer', right_on = 'customer_id', how = 'left')
# Out:
#    order_id  order_date   amount  customer  customer_id first_name  \
# 0         1  07/04/1776  $234.56         1          1.0     George
# 1         2  03/14/1760   $78.50         3          3.0     Thomas
# 2         3  05/23/1784  $124.00         2          2.0       John
# 3         4  09/03/1790   $65.50         3          3.0     Thomas
# 4         5  07/21/1795   $25.50        10          NaN        NaN
# 5         6  11/27/1787   $14.40         9          NaN        NaN
#
#     last_name                email                    address  \
# 0  Washington  gwashington@usa.gov         3200 Mt Vernon Hwy
# 1   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 2       Adams       jadams@usa.gov            1250 Hancock St
# 3   Jefferson   tjefferson@usa.gov  931 Thomas Jefferson Pkwy
# 4         NaN                  NaN                        NaN
# 5         NaN                  NaN                        NaN
#
#               city state  zipcode
# 0     Mount Vernon    VA  22121.0
# 1  Charlottesville    VA  22902.0
# 2           Quincy    MA   2169.0
# 3  Charlottesville    VA  22902.0
# 4              NaN   NaN      NaN
# 5              NaN   NaN      NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Transforming Columns using map, apply and applymap

# %%
def addition(a):
    return a+4

# %%
add = lambda x : x+2

# %%
add(2)
# Out:
# 4

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.Age = df.Age.map(lambda x: x+4)

# %%
df.Age = df.Age.map(addition)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  30.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  46.0      1
# 2                             Heikkinen, Miss. Laina  female  34.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  43.0      1
# 4                           Allen, Mr. William Henry    male  43.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.apply(lambda x: x.as_type).head()

# %%
df[['Age','Fare']].applymap(lambda x : x+2).head()
# Out:
#     Age     Fare
# 0  24.0   9.2500
# 1  40.0  73.2833
# 2  28.0   9.9250
# 3  37.0  55.1000
# 4  37.0  10.0500

# %% [markdown]
# #### How to remove duplicate rows

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(subset =)

# %% [markdown]
# #### Working with Date and time

# %% [markdown]
# #### Exporting Output

# %%
#Writing to a csv file

df.to_csv(filename,)

# %% [markdown]
# #### Reading and writing from/to excel files

# %%
pd.read_excel()
